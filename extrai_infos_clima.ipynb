# %%
"""Nada mais é do que um arquivo de configuração para o script extrai_infos_clima.py"""
import os
from os.path import join
import pandas as pd # type: ignore
from datetime import datetime, timedelta
from dotenv import load_dotenv # type: ignore

load_dotenv()

# intervalo de datas
data_inicio = datetime.today()
data_fim = data_inicio + timedelta(days=7)

# formatando as datas
data_inicio = data_inicio.strftime('%Y-%m-%d')
data_fim = data_fim.strftime('%Y-%m-%d')

city = 'Boston'
key = os.environ['API_KEY']

URL = join('https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/',
           f'{city}/{data_inicio}/{data_fim}?unitGroup=metric&include=days&key={key}&contentType=csv')

dados = pd.read_csv(URL)

# %%
dados.head()
# Out:
#                         name    datetime  tempmax  tempmin  temp  \
# 0  Boston, MA, United States  2024-09-30     16.7     13.9  15.3
# 1  Boston, MA, United States  2024-10-01     16.7     15.0  15.5
# 2  Boston, MA, United States  2024-10-02     16.2     14.5  15.4
# 3  Boston, MA, United States  2024-10-03     20.6     14.4  17.5
# 4  Boston, MA, United States  2024-10-04     22.6     14.5  18.3
#
#    feelslikemax  feelslikemin  feelslike   dew  humidity  ...  solarenergy  \
# 0          16.7          13.9       15.3  13.2      87.7  ...         15.2
# 1          16.7          15.0       15.5  13.4      87.0  ...          9.3
# 2          16.2          14.5       15.4  12.4      82.3  ...         14.6
# 3          20.6          14.4       17.5  12.9      75.4  ...         17.8
# 4          22.6          14.5       18.3  13.0      72.7  ...         17.9
#
#    uvindex  severerisk              sunrise               sunset  moonphase  \
# 0        5          10  2024-09-30T06:40:47  2024-09-30T18:26:38       0.93
# 1        3          10  2024-10-01T06:41:53  2024-10-01T18:24:53       0.96
# 2        4          10  2024-10-02T06:42:59  2024-10-02T18:23:09       0.00
# 3        5          10  2024-10-03T06:44:05  2024-10-03T18:21:26       0.03
# 4        6          10  2024-10-04T06:45:12  2024-10-04T18:19:43       0.06
#
#          conditions                        description               icon  \
# 0  Partially cloudy  Partly cloudy throughout the day.  partly-cloudy-day
# 1  Partially cloudy  Partly cloudy throughout the day.  partly-cloudy-day
# 2  Partially cloudy  Partly cloudy throughout the day.  partly-cloudy-day
# 3  Partially cloudy  Partly cloudy throughout the day.  partly-cloudy-day
# 4  Partially cloudy  Partly cloudy throughout the day.  partly-cloudy-day
#
#    stations
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 33 columns]

# %%
file_path = f"./semana={data_inicio}/"
os.mkdir(file_path)

dados.to_csv(file_path + 'dados_brutos.csv')
dados[['datetime', 'tempmin', 'temp', 'tempmax']].to_csv(
    file_path + 'temperaturas.csv')
dados[['datetime', 'description', 'icon']].to_csv(file_path + 'condicoes.csv')
